# %%
import sys
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter('ignore')

# %%
sys.path.append("../../oats")
from oats.biology.groupings import Groupings
from oats.utils.utils import save_to_pickle
from oats.nlp.preprocess import replace_delimiter, concatenate_with_delim

# %% [markdown]
# Paths to input files from databases or papers. Some others are specified below in the dictionaries as well.

# %%
lloyd_meinke_cleaned_supplemental_table_path_hierarchy = "../papers/lloyd_meinke_2012/versions_cleaned_by_me/192393Table_S1_Final.csv"
lloyd_meinke_cleaned_supplemental_table_path_mappings = "../papers/lloyd_meinke_2012/versions_cleaned_by_me/192393Table_S2_Final_Revised.csv"

# %% [markdown]
# Paths to the csv files that are created for each type of data for grouping genes.

# %%
lloyd_meinke_subsets_output_path = "../reshaped_data/lloyd_meinke_subsets.csv"
lloyd_meinke_classes_output_path = "../reshaped_data/lloyd_meinke_classes.csv"
kegg_pathways_output_path = "../reshaped_data/kegg_pathways.csv"
plantcyc_pathways_output_path = "../reshaped_data/plantcyc_pathways.csv"

# %% [markdown]
# Paths to the csv files that are created to specify the mappings between IDs and names for each group.

# %%
lloyd_meinke_subsets_name_mapping_path = "../reshaped_data/lloyd_meinke_subsets_name_map.csv"
lloyd_meinke_classes_name_mapping_path = "../reshaped_data/lloyd_meinke_classes_name_map.csv"
kegg_pathways_name_mapping_path = "../reshaped_data/kegg_pathways_name_map.csv"
plantcyc_pathways_name_mapping_path = "../reshaped_data/plantcyc_pathways_name_map.csv"

# %% [markdown]
# PlantCyc

# %% [markdown]
# Mapping between species codes and files downloaded from PlantCyc.

# %%
plantcyc_paths_dictionary = {
    "ath":"../databases/plantcyc/aracyc_pathways.20180702", 
    "zma":"../databases/plantcyc/corncyc_pathways.20180702", 
    "mtr":"../databases/plantcyc/mtruncatulacyc_pathways.20180702", 
    "osa":"../databases/plantcyc/oryzacyc_pathways.20180702", 
    "gmx":"../databases/plantcyc/soycyc_pathways.20180702",
    "sly":"../databases/plantcyc/tomatocyc_pathways.20180702"}

# %% [markdown]
# Create and save the pathways object using PlantCyc.

# %%
plantcyc_df = Groupings.get_dataframe_for_plantcyc(paths=plantcyc_paths_dictionary)
plantcyc_df.to_csv(plantcyc_pathways_output_path, index=False)
plantcyc_name_mapping = {row.pathway_id:row.pathway_name for row in plantcyc_df.itertuples()}
pd.DataFrame(plantcyc_name_mapping.items(), columns=["group_id","group_name"]).to_csv(plantcyc_pathways_name_mapping_path, index=False)

# %% [markdown]
# KEGG

# %% [markdown]
# Mapping between species codes and files saved using another script that uses the KEGG REST API.

# %% [markdown]
# kegg_paths_dictionary = {<br>
#     "ath":"/Users/irbraun/plant-data/databases/kegg/ath_pathway_files_from_api",<br>
#     "zma":"/Users/irbraun/plant-data/databases/kegg/zma_pathway_files_from_api",<br>
#     "osa":"/Users/irbraun/plant-data/databases/kegg/osa_pathway_files_from_api",<br>
#     "mtr":"/Users/irbraun/plant-data/databases/kegg/mtr_pathway_files_from_api",<br>
#     "gmx":"/Users/irbraun/plant-data/databases/kegg/gmx_pathway_files_from_api",<br>
#     "sly":"/Users/irbraun/plant-data/databases/kegg/sly_pathway_files_from_api",<br>
#     "hsa":"/Users/irbraun/plant-data/databases/kegg/hsa_pathway_files_from_api",<br>

# %%
path_to_kegg = "../databases/kegg/"

# %%
ath = str(path_to_kegg) + "ath_pathway_files_from_api"
zma = str(path_to_kegg) + "zma_pathway_files_from_api"
osa = str(path_to_kegg) + "osa_pathway_files_from_api"
mtr = str(path_to_kegg) + "mtr_pathway_files_from_api"
gmx = str(path_to_kegg) + "gmx_pathway_files_from_api"
sly = str(path_to_kegg) + "sly_pathway_files_from_api"
hsa = str(path_to_kegg) + "hsa_pathway_files_from_api"

# %%
kegg_paths_dictionary = {
	"ath":str(ath),
	"zma":str(zma),
	"osa":str(osa),
	"mtr":str(mtr),
	"gmx":str(gmx),
	"sly":str(sly),
	"hsa":str(hsa)
}

# %%
kegg_df = Groupings.get_dataframe_for_kegg(paths=kegg_paths_dictionary)
kegg_df.to_csv(kegg_pathways_output_path, index=False)
kegg_name_mapping = {row.pathway_id:row.pathway_name for row in kegg_df.itertuples()}
pd.DataFrame(kegg_name_mapping.items(), columns=["group_id","group_name"]).to_csv(kegg_pathways_name_mapping_path, index=False)
# Out:
# ../databases/kegg/ath_pathway_files_from_api/path_ath00901.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00740.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01100.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04070.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01210.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00450.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00906.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00270.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00908.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01250.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00410.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00071.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03040.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00941.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00590.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00230.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00999.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00640.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00950.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00195.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03430.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03018.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00510.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00965.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00261.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00600.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01040.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04130.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03250.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00052.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00020.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00565.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00562.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00910.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04145.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00330.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00780.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00650.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00998.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00591.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00940.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00360.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03420.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03008.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00500.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04120.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00909.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00030.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00480.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00900.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00790.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00563.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04144.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00750.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01110.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01200.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00440.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03010.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00564.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00260.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00601.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00053.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00511.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04136.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01240.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00400.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00061.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03050.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00710.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00130.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00220.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03022.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01232.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04712.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00785.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03013.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00670.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00340.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00960.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04016.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00190.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00520.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00062.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00630.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00280.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03440.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00010.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00300.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00920.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00770.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00543.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00592.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03030.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00232.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00460.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00073.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00860.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00944.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00240.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00531.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00380.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00730.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00903.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01212.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath02010.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04075.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00904.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00760.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03020.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath01230.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00470.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00250.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00196.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00514.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00966.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03060.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00603.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00430.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00051.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00513.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00604.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00561.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03015.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00100.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04146.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04141.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04626.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00660.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00905.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00902.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00350.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00970.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath04122.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03410.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00040.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00942.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00072.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00945.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00290.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00620.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath03450.txt
# ../databases/kegg/ath_pathway_files_from_api/path_ath00310.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00730.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00380.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04075.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma02010.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01212.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00904.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00903.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00232.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03030.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00460.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00770.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00592.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00543.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00531.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00860.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00073.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00240.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00944.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00062.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00280.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00630.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00520.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00190.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00300.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00920.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03440.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00010.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00785.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04712.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00670.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03013.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04016.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00340.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00960.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00072.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00620.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00290.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00945.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00942.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00310.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03450.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00902.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00905.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00660.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04626.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03410.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04122.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00040.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00350.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00970.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00604.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00513.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00603.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03060.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00966.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00514.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00051.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00430.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04141.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04146.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00100.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03015.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00561.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03020.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01230.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00470.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00760.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00402.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00196.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00250.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04130.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00600.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01040.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00261.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00965.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00052.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03250.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03018.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00510.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04145.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00910.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00562.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00780.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00330.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00020.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00565.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00640.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03430.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00195.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00950.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00941.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00071.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01250.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00410.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03040.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00230.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00999.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00590.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01210.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00450.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00906.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04070.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00740.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01100.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00270.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00908.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00710.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00061.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01240.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00400.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03050.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03022.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00220.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01232.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00130.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01200.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00440.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00564.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03010.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04144.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00563.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00750.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma01110.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04136.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00511.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00601.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00260.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00053.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma04120.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00909.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03008.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00500.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00900.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00790.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00480.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00030.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00591.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00650.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00998.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma03420.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00940.txt
# ../databases/kegg/zma_pathway_files_from_api/path_zma00360.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00531.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00073.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00860.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00944.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00240.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03030.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00232.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00460.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00770.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00543.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00592.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04075.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01212.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa02010.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00904.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00903.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00380.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00730.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04016.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00340.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00960.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00785.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04712.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03013.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00670.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00300.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00920.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03440.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00010.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00062.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00630.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00280.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00190.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00520.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03410.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04122.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00040.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00350.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00970.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00902.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00660.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00905.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04626.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00310.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03450.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00072.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00290.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00945.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00620.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00942.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00402.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00250.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00196.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03020.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00470.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01230.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00760.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04141.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04146.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00561.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00100.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03015.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00513.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00604.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00514.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00966.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03060.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00603.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00430.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00051.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00195.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03430.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00950.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00640.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04145.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00562.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00910.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00330.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00780.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00020.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00565.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04130.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00965.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00261.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01040.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00600.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03250.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00052.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03018.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00510.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00270.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00908.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00450.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01210.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00906.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04070.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01100.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00740.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00230.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00999.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00590.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00941.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00410.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01250.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00071.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03040.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04136.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00511.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00260.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00601.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00053.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00440.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01200.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03010.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00564.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04144.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00563.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01110.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00750.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00220.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03022.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01232.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00130.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00710.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00400.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa01240.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00061.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03050.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03420.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00940.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00360.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00591.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00650.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00998.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00900.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00790.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00030.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00480.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa04120.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00909.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa03008.txt
# ../databases/kegg/osa_pathway_files_from_api/path_osa00500.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00230.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00999.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00590.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00941.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01250.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00410.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00071.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03040.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00270.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00908.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01210.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00450.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00906.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00740.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01100.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04070.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00910.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00562.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04145.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00780.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00330.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00020.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00565.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00261.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00600.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01040.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00965.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04130.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00052.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03250.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03018.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00510.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03430.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00195.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00950.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00640.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00900.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00790.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00480.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00030.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04120.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00909.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03008.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00500.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03420.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00940.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00360.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00591.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00650.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00998.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03022.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00220.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01232.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00130.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00523.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00710.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01240.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00400.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00061.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03050.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00511.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04136.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00260.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00601.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00053.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01200.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00440.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03010.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00564.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00563.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04144.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00750.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01110.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00300.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00920.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03440.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00010.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00062.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00280.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00630.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00520.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00190.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04016.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00340.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00960.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04712.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00785.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00670.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03013.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr02010.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01212.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04075.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00904.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00903.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00730.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00380.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00531.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00943.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00073.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00860.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00240.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00944.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00232.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03030.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00460.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00770.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00592.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00543.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04141.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00561.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03015.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00100.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04146.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00604.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00513.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00603.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00966.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00514.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03060.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00430.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00051.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00250.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00196.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03020.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr01230.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00470.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00760.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00310.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03450.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00072.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00620.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00945.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00290.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04122.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr03410.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00040.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00350.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00970.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr04626.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00905.txt
# ../databases/kegg/mtr_pathway_files_from_api/path_mtr00660.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00062.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00280.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00630.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00520.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00190.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00300.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00920.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03440.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00010.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04712.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00785.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00670.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03013.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04016.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00340.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00960.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00730.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00380.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx02010.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01212.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04075.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00904.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00903.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00232.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03030.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00460.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00770.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00592.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00543.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00943.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00531.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00860.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00073.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00240.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00944.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00604.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00513.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00603.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03060.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00514.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00966.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00051.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00430.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04141.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00100.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03015.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00561.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04146.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03020.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01230.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00470.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00760.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00196.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00250.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00072.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00620.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00290.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00945.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00942.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00310.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03450.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04626.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00905.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00660.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04122.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03410.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00040.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00350.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00970.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00941.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00071.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01250.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00410.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03040.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00230.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00999.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00590.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01210.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00450.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00906.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00740.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01100.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04070.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00270.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00908.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00600.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01040.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00261.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00965.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04130.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00052.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03250.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03018.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00510.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00562.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00910.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04145.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00780.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00330.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00020.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00565.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00640.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03430.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00195.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00950.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04120.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00909.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03008.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00500.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00900.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00790.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00480.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00030.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00591.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00650.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00998.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03420.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00940.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00360.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00710.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00061.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01240.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00400.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03050.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03022.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00220.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01232.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00130.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01200.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00440.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00564.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx03010.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00563.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04144.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00750.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx01110.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00511.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx04136.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00601.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00260.txt
# ../databases/kegg/gmx_pathway_files_from_api/path_gmx00053.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly04141.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly04146.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly03015.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00100.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00561.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00513.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00604.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00051.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00430.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly03060.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00514.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00966.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00603.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00196.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00250.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly01230.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00470.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly03020.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00760.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00310.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly03450.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00290.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00945.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00620.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00072.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00942.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00040.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly03410.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly04122.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00970.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00350.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00902.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00660.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00905.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly04626.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00920.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00300.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00010.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly03440.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00630.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00280.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00062.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00190.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00520.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly04016.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00960.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00340.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly03013.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00670.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00785.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly04712.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly00904.txt
# ../databases/kegg/sly_pathway_files_from_api/path_sly04075.txt
# ...
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04146.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04630.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03015.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00100.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00561.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04929.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04714.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04062.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00830.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04713.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04141.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04520.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05416.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00640.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04392.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05162.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04722.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04918.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04725.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05165.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04260.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04964.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05033.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04916.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03265.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05200.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05207.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04750.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05110.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04215.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05034.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04911.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05323.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03430.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03018.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04924.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04137.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00510.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04923.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04130.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00600.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01040.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04068.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00052.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03250.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05235.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04014.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00020.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04710.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05150.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04371.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04066.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04142.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05415.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00565.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04145.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05412.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00562.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00910.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00780.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00330.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04061.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04622.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04070.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05146.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00740.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01100.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04360.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04659.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01210.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00450.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04625.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04940.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00270.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05017.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04657.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04540.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04932.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05224.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05133.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05223.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05134.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04650.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05010.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04935.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05216.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00071.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01250.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00410.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03040.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00534.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05332.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00533.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04114.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05022.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04662.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05211.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01521.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00590.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00120.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04975.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04610.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00230.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05218.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05340.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04972.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04144.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00563.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00750.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04060.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01200.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00440.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04370.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04950.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05414.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00564.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03010.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05310.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04922.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04550.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00601.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00260.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00053.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04015.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04012.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04925.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04136.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04640.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00511.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00061.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01240.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00400.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05206.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04330.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04910.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05322.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03050.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00524.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04213.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05032.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04672.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04917.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00980.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03264.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04020.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04919.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04724.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05164.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04261.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00130.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04510.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04962.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03022.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05208.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00220.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00472.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa01232.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05163.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04723.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00650.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05219.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04973.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00591.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04974.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04270.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04611.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00532.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04115.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05210.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00360.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04740.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05100.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05217.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03420.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04664.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04810.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05222.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03008.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05135.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00500.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04934.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05016.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04933.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04120.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05225.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05132.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa05140.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04658.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00480.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00030.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa03460.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04152.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00900.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04623.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa04071.txt
# ../databases/kegg/hsa_pathway_files_from_api/path_hsa00790.txt
#       species pathway_id                                       pathway_name  \
# 0         hsa    ko00770  Pantothenate and CoA biosynthesis - Homo sapie...
# 1         hsa    ko00770  Pantothenate and CoA biosynthesis - Homo sapie...
# 2         hsa    ko00770  Pantothenate and CoA biosynthesis - Homo sapie...
# 3         hsa    ko00770  Pantothenate and CoA biosynthesis - Homo sapie...
# 4         hsa    ko00770  Pantothenate and CoA biosynthesis - Homo sapie...
# ...       ...        ...                                                ...
# 33359     hsa    ko00790         Folate biosynthesis - Homo sapiens (human)
# 33360     hsa    ko00790         Folate biosynthesis - Homo sapiens (human)
# 33361     hsa    ko00790         Folate biosynthesis - Homo sapiens (human)
# 33362     hsa    ko00790         Folate biosynthesis - Homo sapiens (human)
# 33363     hsa    ko00790         Folate biosynthesis - Homo sapiens (human)
#
#                                               gene_names ncbi_id uniprot_id  \
# 0                            PANK1|pantothenate kinase 1   53354
# 1                            PANK3|pantothenate kinase 3   79646
# 2                            PANK2|pantothenate kinase 2   80025
# 3            PPCS|phosphopantothenoylcysteine synthetase   79717
# 4        PPCDC|phosphopantothenoylcysteine decarboxylase   60490
# ...                                                  ...     ...        ...
# 33359                      TPH1|tryptophan hydroxylase 1    7166
# 33360  MOCS1|molybdenum cofactor synthesis 1  [EC:4.1...    4337
# 33361              MOCS2|molybdenum cofactor synthesis 2    4338
# 33362              GPHN|gephyrin  [EC:2.10.1.1 2.7.7.75]   10243
# 33363                MOCOS|molybdenum cofactor sulfurase   55034
#
#        ko_number     ec_number gene_identifiers group_ids  \
# 0      KO:K09680   EC:2.7.1.33
# 1      KO:K09680   EC:2.7.1.33
# 2      KO:K09680   EC:2.7.1.33
# 3      KO:K01922   EC:6.3.2.51
# 4      KO:K01598   EC:4.1.1.36
# ...          ...           ...              ...       ...
# 33359  KO:K00502  EC:1.14.16.4
# 33360  KO:K20967
# 33361  KO:K03635   EC:2.8.1.12
# 33362  KO:K15376
# 33363  KO:K15631    EC:2.8.1.9
#
#                                           pathway_class pathway_id_for_species
# 0      Metabolism; Metabolism of cofactors and vitamins               hsa00770
# 1      Metabolism; Metabolism of cofactors and vitamins               hsa00770
# 2      Metabolism; Metabolism of cofactors and vitamins               hsa00770
# 3      Metabolism; Metabolism of cofactors and vitamins               hsa00770
# 4      Metabolism; Metabolism of cofactors and vitamins               hsa00770
# ...                                                 ...                    ...
# 33359  Metabolism; Metabolism of cofactors and vitamins               hsa00790
# 33360  Metabolism; Metabolism of cofactors and vitamins               hsa00790
# 33361  Metabolism; Metabolism of cofactors and vitamins               hsa00790
# 33362  Metabolism; Metabolism of cofactors and vitamins               hsa00790
# 33363  Metabolism; Metabolism of cofactors and vitamins               hsa00790
#
# [33364 rows x 12 columns]

# %% [markdown]
# Lloyd and Meinke et al., 2012

# %% [markdown]
# Some preprocessing on the supplemental file from Lloyd and Meinke, 2012 paper to extrac the columns used.

# %%
df = pd.read_csv(lloyd_meinke_cleaned_supplemental_table_path_mappings)
df.fillna("", inplace=True)
combine_columns = lambda row, columns: concatenate_with_delim("|", [row[column] for column in columns])
df["Alias Symbols"] = df["Alias Symbols"].apply(lambda x: replace_delimiter(text=x, old_delim=";", new_delim="|"))
df["gene_identifiers"] = df.apply(lambda x: combine_columns(x, ["Locus", "Gene Symbol", "Alias Symbols", "Full Gene Name"]), axis=1)

# %% [markdown]
# Specific to classes (more general).

# %%
df_class = df[["Phenotype Classb", "gene_identifiers"]]
df_class["species"] = "ath"
df_class.columns = ["group_ids", "gene_identifiers","species"]
df_class = df_class[["species", "group_ids", "gene_identifiers"]]
df_class.to_csv(lloyd_meinke_classes_output_path, index=False)

# %% [markdown]
# Specific to subsets (more specific).

# %%
df_subset = df[["Phenotype Subsetsb", "gene_identifiers"]]
df_subset["species"] = "ath"
df_subset.columns = ["group_ids", "gene_identifiers","species"]
df_subset = df_subset[["species", "group_ids", "gene_identifiers"]]
df_subset["group_ids"] = df_subset["group_ids"].apply(lambda x: x.replace("W:", "").replace("S:","").replace("(",",").replace(")",",").replace(";",","))
df_subset["group_ids"] = df_subset["group_ids"].apply(lambda x: replace_delimiter(text=x, old_delim=",", new_delim="|"))
df_subset.to_csv(lloyd_meinke_subsets_output_path, index=False)

# %% [markdown]
# Provide a mapping from subset or class IDs to the longer names that define them.

# %%
df = pd.read_csv(lloyd_meinke_cleaned_supplemental_table_path_hierarchy)
subset_id_to_name_dict = {row[5]:row[7] for row in df.itertuples()}
class_id_to_name_dict = {row[3]:row[4] for row in df.itertuples()}
pd.DataFrame(subset_id_to_name_dict.items(), columns=["group_id","group_name"]).to_csv(lloyd_meinke_subsets_name_mapping_path, index=False)
pd.DataFrame(class_id_to_name_dict.items(), columns=["group_id","group_name"]).to_csv(lloyd_meinke_classes_name_mapping_path, index=False)

# %% [markdown]
# Briefly checking whether groupings object can be successfully built from the created files.<br>
# Create actual oats.Grouping objects using those CSV files that were created previously, and quick check of the contents.

# %%
print(Groupings(path=lloyd_meinke_subsets_output_path, name_mapping=subset_id_to_name_dict).describe())
print(Groupings(path=lloyd_meinke_classes_output_path, name_mapping=class_id_to_name_dict).describe())
print(Groupings(path=kegg_pathways_output_path, name_mapping=kegg_name_mapping).describe())
print(Groupings(path=plantcyc_pathways_output_path, name_mapping=plantcyc_name_mapping).describe())
